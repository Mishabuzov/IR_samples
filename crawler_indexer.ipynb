# %% [markdown]
# # Building inverted index and answering queries
#
# Here is presented a simple standard document processing pipeline with a simple search engine based on it: starting from crawling documents, then building an inverted index, answering queries using this index, and organizing it as a simple web server.

# %% [markdown]
# # 1. Preprocessing

# %% [markdown]
# First, here is a unified approach to documents preprocessing, and Preprocessor class is responsible for it.

# %%
import nltk

class Preprocessor:

    def __init__(self):
        self.stop_words = {'a', 'an', 'and', 'are', 'as', 'at', 'be', 'by',
                           'for', 'from', 'has', 'he', 'in', 'is', 'it', 'its',
                           'of', 'on', 'that', 'the', 'to', 'was', 'were',
                           'will', 'with'}
        self.ps = nltk.stem.PorterStemmer()

    def tokenize(self, text):
        return nltk.word_tokenize(text)

    def stem(self, word, stemmer):
        return stemmer.stem(word)

    def is_apt_word(self, word: str):
        return word not in self.stop_words and word.isalpha()

    def preprocess(self, text):
        """
        tokenize lowercased text and stem it, ignoring not appropriate words
        """
        text = text.lower()
        tokenized_text = self.tokenize(text)
        stemmed = [self.stem(word, self.ps) for word in tokenized_text]

        filtered_words = []
        for word in stemmed:
            if self.is_apt_word(word):
                filtered_words.append(word)

        return filtered_words

# %% [markdown]
# ## 1.1. Tests ##

# %%
prep = Preprocessor()
text = 'To be, or not to be, that is the question'

assert prep.tokenize(text) == ['To', 'be', ',', 'or', 'not', 'to', 'be', ',', 'that', 'is', 'the', 'question']
assert prep.stem('retrieval', prep.ps) == 'retriev'
assert prep.is_apt_word('qwerty123') is False
assert prep.preprocess(text) == ['or', 'not', 'question']

# %% [markdown]
# # 2. Crawling and Indexing

# %% [markdown]
# ## 2.1 Base classes

# %% [markdown]
# Here are some base classes that needed for writing indexer.

# %%
import requests
from urllib.parse import quote
from bs4 import BeautifulSoup
from bs4.element import Comment
import urllib.parse
import os


class Document:

    def __init__(self, url):
        self.url = url

    def download(self):

        def is_html_document(response: requests.Response):
            if response is not None \
                    and response.headers['content-type'] is not None \
                    and "html" in response.headers['content-type']:
                return True

        try:
            response = requests.get(self.url)
            self.content = []
            if response.status_code == 200 and is_html_document(response):
                self.content = response.content
                if self.content is not None and len(self.content) > 0:
                    # print("from internet")
                    return True  # check if page content is not empty.
            return False
        except:
            return False

    def get_file_name(self, path):
        return os.path.join(path, quote(self.url).replace('/', '_'))

    def load(self, path):
        try:
            with open(self.get_file_name(path), 'rb') as f:
                self.content = f.read()
                # print("from disk")
        except:
            return False
        return True

    def get(self, path):
        if not self.load(path):
            return self.download()
        return True

    def persist(self, path):
        with open(self.get_file_name(path), 'wb') as f:
            f.write(self.content)


class HtmlDocument(Document):

    def normalize(self, href):
        if href is not None and href[:4] != 'http':
            href = urllib.parse.urljoin(self.url, href)
        return href

    def parse(self):

        def is_text_inside_main_div(element):
            """
            Check if text inside following tag construction:
            <div class="StandardArticleBody_body"/><p>...</p></div>
            which is the main text container.
            :param element: Actually text element.
            """
            return element.parent.parent is not None \
                   and element.parent.parent.name == 'div' \
                   and 'class' in element.parent.parent.attrs \
                   and 'StandardArticleBody_body' in element.parent.parent.attrs['class']

        def tag_visible(element):
            if element.parent.name in ['style', 'script', 'head', 'title',
                                       'meta', '[document]']:
                return False
            if isinstance(element, Comment):
                return False
            return is_text_inside_main_div(element)

        def is_available_content_type(href):
            return not (href.endswith(".pdf") or href.endswith(".mp3")
                        or href.endswith(".avi") or href.endswith(".mp4")
                        or href.endswith(".txt"))

        model = BeautifulSoup(self.content)

        self.anchors = []
        a = model.find_all('a')
        
        for anchor in a:
            href = self.normalize(anchor.get('href'))
            if href is None:
                continue
            text = anchor.text

            if href.startswith('https://www.reuters.com/') \
                    and is_available_content_type(href):
                self.anchors.append((text, href))

        texts = model.findAll(text=True)
        visible_texts = filter(tag_visible, texts)
        self.text = u" ".join(t.strip() for t in visible_texts)

# %% [markdown]
# ## 2.2 Main class

# %% [markdown]
# The main indexer logic is here. It organized as a crawler generator that adds certain visited pages to inverted index and saves them on disk.
#
# - `crawl_generator_for_index` method crawles the given website doing BFS, starting from `source` within given `depth`. Considers only inner pages (of a form https://www.reuters.com/...) for visiting. To speed up, doesn't consider for visiting pages with content type other than html: '.pdf', '.mp3', '.avi', '.mp4', '.txt'. If encounters an article page (of a form https://www.reuters.com/article/...), saves its content in a file in `collection_path` folder and populates the inverted index calling `index_doc` method. When done, saves on disk three resulting dictionaries:
#     - `doc_urls`, `doc_id:url`
#     - `index`, `term:[collection_frequency, (doc_id_1, doc_freq_1), (doc_id_2, doc_freq_2), ...]`
#     - `doc_lengths`, `doc_id:doc_length`
#
#     `limit` parameter is given for testing - if not `None`, the loop is broken when number of saved articles exceeds the `limit` and return without writing dictionaries to disk.
#
#
# - `index_doc` method parses and preprocesses the content of a `doc` and adds it to the inverted index. Also keeps track of document lengths in a `doc_lengths` dictionary.

# %%
from queue import Queue
import pickle
from pathlib import Path


class Indexer:

    def __init__(self):
        # dictionaries to populate
        self.doc_id = 0  # also consider it as a saved document counter.
        self.doc_urls = {}
        self.index = {}
        self.doc_lengths = {}
        # preprocessor
        self.prep = Preprocessor()

    def crawl_generator_for_index(self, source, depth,
                                  collection_path="collection", limit=None):

        def is_article(url: str):
            return url.startswith("https://www.reuters.com/article/")

        def process_article(article: HtmlDocument):
            """
            save article's content and populates the inverted index.
            """
            self.doc_id += 1
            article.persist(collection_path)
            self.index_doc(article, self.doc_id)

        def save_dictionaries_on_disk():
            with open('inverted_index.p', 'wb') as f:
                pickle.dump(self.index, f)
            with open('doc_lengths.p', 'wb') as f:
                pickle.dump(self.doc_lengths, f)
            with open('doc_urls.p', 'wb') as f:
                pickle.dump(self.doc_urls, f)

        # create a path if it does not exist.
        Path(collection_path).mkdir(parents=True, exist_ok=True)

        q = Queue()
        q.put((source, 0))
        visited = set()
        while not q.empty():
            url, url_depth = q.get()
            if url not in visited:
                visited.add(url)
                try:
                    doc = HtmlDocument(url)
                    if doc.get(collection_path):
                        doc.parse()
                    else:
                        continue
                    for a in doc.anchors:
                        if url_depth + 1 < depth:
                            q.put((a[1], url_depth + 1))
                    yield doc

                    if is_article(doc.url):
                        process_article(doc)
                        if limit is not None and self.doc_id >= limit:
                            # if limit is reached - end the cycle
                            break  # stop finding articles.
                except FileNotFoundError as e:
                    print("Analyzing", url, "led to FileNotFoundError")

        if q.empty():
            save_dictionaries_on_disk()

    def index_doc(self, doc, doc_id):

        def create_doc_vocabulary(preprocessed_text):
            freq_vocabulary = {}  # term: term_frequency
            for term in preprocessed_text:
                if term not in freq_vocabulary:
                    freq_vocabulary[term] = 1
                else:
                    freq_vocabulary[term] += 1
            return freq_vocabulary

        def fill_inverted_index_dict(preprocessed_text):
            freq_vocabulary = create_doc_vocabulary(preprocessed_text)
            for term, term_freq in freq_vocabulary.items():
                if term not in self.index:
                    self.index[term] = [term_freq, (doc_id, term_freq)]
                else:
                    self.index[term].append((doc_id, term_freq))
                    self.index[term][0] += term_freq

        preprocessed_text = self.prep.preprocess(doc.text)
        self.doc_urls[doc_id] = doc.url
        fill_inverted_index_dict(preprocessed_text)
        self.doc_lengths[doc_id] = len(preprocessed_text)

# %% [markdown]
# ## 2.3. Tests ##

# %%
indexer = Indexer()
k = 1
for c in indexer.crawl_generator_for_index("https://www.reuters.com/news/us", 2, "test_collection", 5):
    print(k, c.url)
    k+=1

assert type(indexer.index) is dict
assert type(indexer.index['reuter']) is list
assert type(indexer.index['reuter'][0]) is int
assert type(indexer.index['reuter'][1]) is tuple
# Out:
# 1 https://www.reuters.com/news/us
# 2 https://www.reuters.com/
# 3 https://www.reuters.com/finance
# 4 https://www.reuters.com/finance/markets
# 5 https://www.reuters.com/news/world
# 6 https://www.reuters.com/politics
# 7 https://www.reuters.com/video
# 8 https://www.reuters.com/news/archive/healthNews
# 9 https://www.reuters.com/article/us-health-coronavirus-exclusive/exclusive-emails-reveal-breakdowns-in-u-s-drive-through-virus-testing-idUSKCN21W2KP
# 10 https://www.reuters.com/news/archive/politicsNews
# 11 https://www.reuters.com/article/us-health-coronavirus-usa-new-york/new-york-hospitalizations-fall-for-first-time-in-coronavirus-pandemic-governor-idUSKCN21W2DH
# 12 https://www.reuters.com/article/us-health-coronavirus-usa/trump-speaks-of-mutiny-as-cuomo-dismisses-premature-coronavirus-reopening-idUSKCN21W20G
# 13 https://www.reuters.com/article/us-health-coronavirus-usa-congress/republicans-warn-coronavirus-aid-program-running-out-of-cash-idUSKCN21W20O
# 14 https://www.reuters.com/article/us-health-coronavirus-trump-ventilators/trump-to-announce-ventilator-loan-plan-to-fight-virus-idUSKCN21W2EZ

# %% [markdown]
# ## 2.4 Building index

# %%
indexer = Indexer()
k = 1
for c in indexer.crawl_generator_for_index("https://www.reuters.com/", 3, "docs_collection"):
    print(k, c.url)
    k+=1
# Out:
# 1 https://www.reuters.com/
# 2 https://www.reuters.com/home
# 3 https://www.reuters.com/finance
# 4 https://www.reuters.com/legal
# 5 https://www.reuters.com/finance/deals
# 6 https://www.reuters.com/subjects/aerospace-and-defense
# 7 https://www.reuters.com/subjects/banks
# 8 https://www.reuters.com/subjects/autos
# 9 https://www.reuters.com/finance/summits
# 10 https://www.reuters.com/subjects/sustainable-business
# 11 https://www.reuters.com/the-world-at-work
# 12 https://www.reuters.com/finance/markets
# 13 https://www.reuters.com/finance/markets/us
# 14 https://www.reuters.com/finance/markets/europe
# 15 https://www.reuters.com/finance/markets/asia
# 16 https://www.reuters.com/finance/global-market-data
# 17 https://www.reuters.com/markets/stocks
# 18 https://www.reuters.com/markets/bonds
# 19 https://www.reuters.com/markets/currencies
# 20 https://www.reuters.com/markets/commodities
# 21 https://www.reuters.com/finance/funds
# 22 https://www.reuters.com/finance/EarningsUS
# 23 https://www.reuters.com/finance/markets/dividends
# 24 https://www.reuters.com/finance/exchange-traded-funds
# 25 https://www.reuters.com/subjects/us-lipper-awards
# 26 https://www.reuters.com/news/world
# 27 https://www.reuters.com/news/us
# 28 https://www.reuters.com/subjects/specialReports
# 29 https://www.reuters.com/investigates/
# 30 https://www.reuters.com/subjects/euro-zone
# 31 https://www.reuters.com/subjects/middle-east
# 32 https://www.reuters.com/places/china
# 33 https://www.reuters.com/places/japan
# 34 https://www.reuters.com/places/mexico
# 35 https://www.reuters.com/places/brazil
# 36 https://www.reuters.com/places/africa
# 37 https://www.reuters.com/places/russia
# 38 https://www.reuters.com/places/india
# 39 https://www.reuters.com/politics
# 40 https://www.reuters.com/politics/us-election2020
# 41 https://www.reuters.com/subjects/supreme-court
# 42 https://www.reuters.com/news/technology
# 43 https://www.reuters.com/news/science
# 44 https://www.reuters.com/news/media
# 45 https://www.reuters.com/energy-environment
# 46 https://www.reuters.com/breakingviews
# 47 https://www.reuters.com/video/breakingviews
# 48 https://www.reuters.com/finance/wealth
# 49 https://www.reuters.com/finance/personal-finance/retirement
# 50 https://www.reuters.com/news/lifestyle
# 51 https://www.reuters.com/news/health
# 52 https://www.reuters.com/news/sports/soccer
# 53 https://www.reuters.com/news/sports
# 54 https://www.reuters.com/news/entertainment/arts
# 55 https://www.reuters.com/news/entertainment
# 56 https://www.reuters.com/news/oddlyEnough
# 57 https://www.reuters.com/news/pictures
# 58 https://www.reuters.com/video
# 59 https://www.reuters.com/article/us-health-coronavirus-usa/trump-speaks-of-mutiny-as-cuomo-dismisses-premature-coronavirus-reopening-idUSKCN21W20G
# 60 https://www.reuters.com/article/us-health-coronavirus-usa-new-york/new-york-hospitalizations-fall-for-first-time-in-coronavirus-pandemic-governor-idUSKCN21W2DH
# 61 https://www.reuters.com/article/us-health-coronavirus-usa-states/ten-u-s-states-developing-reopening-plans-account-for-38-of-u-s-economy-idUSKCN21W1D6
# 62 https://www.reuters.com/article/us-health-coronavirus-usa-reopen-explain/explainer-trump-has-little-power-to-restart-u-s-economy-idUSKCN21W15G
# 63 https://www.reuters.com/article/us-health-coronavirus-tracing-explainer/explainer-what-is-contact-tracing-and-how-can-it-help-fight-the-new-coronavirus-idUSKCN21W2N3
# 64 https://www.reuters.com/article/us-health-coronavirus-tracing-apps-expla/explainer-how-smartphone-apps-can-help-contact-trace-the-new-coronavirus-idUSKCN21W2I8
# 65 https://www.reuters.com/article/us-health-coronavirus-exclusive/exclusive-emails-reveal-breakdowns-in-u-s-drive-through-virus-testing-idUSKCN21W2KP
# 66 https://www.reuters.com/article/us-usa-stocks/wall-street-surges-on-hopes-of-lockdown-easing-jpmorgan-kicks-off-earnings-idUSKCN21W179
# 67 https://www.reuters.com/theWire
# 68 https://www.reuters.com/article/us-health-coronavirus-gm/gm-says-it-is-ready-to-deliver-first-batch-of-critical-care-ventilators-idUSKCN21W2OK?il=0
# 69 https://www.reuters.com/article/us-health-coronavirus-fed-bostic/feds-bostic-recovery-may-be-delayed-in-areas-where-virus-peaks-later-idUSKCN21W2ME?il=0
# 70 https://www.reuters.com/article/us-johnson-johnson-results/jj-sees-medical-devices-business-recovery-at-end-of-year-after-taking-coronavirus-hit-idUSKCN21W1AV?il=0
# 71 https://www.reuters.com/article/us-health-coronavirus-zimbabwe/zimbabwe-president-threatens-20-years-jail-over-fake-lockdown-statement-idUSKCN21W1H4?il=0
# 72 https://www.reuters.com/article/us-health-coronavirus-apple/apple-launches-site-to-show-how-coronavirus-lockdowns-affect-movement-idUSKCN21W2IN?il=0
# 73 https://www.reuters.com/article/us-health-coronavirus-usa-cuomo/cuomo-says-if-trump-ordered-new-york-to-reopen-he-wouldnt-do-it-idUSKCN21W1L7?il=0
# 74 https://www.reuters.com/article/us-health-coronavirus-usa/trump-speaks-of-mutiny-as-cuomo-dismisses-premature-coronavirus-reopening-idUSKCN21W20G?il=0
# 75 https://www.reuters.com/article/us-health-coronavirus-usa-new-york/new-york-hospitalizations-fall-for-first-time-in-coronavirus-pandemic-governor-idUSKCN21W2DH?il=0
# 76 https://www.reuters.com/article/us-imf-world-bank-debt-groups/faith-groups-afl-cio-urge-u-s-imf-g20-to-cancel-debt-for-poor-countries-idUSKCN21W2OT?il=0
# 77 https://www.reuters.com/article/us-health-coronavirus-tracing-apps-expla/explainer-how-smartphone-apps-can-help-contact-trace-the-new-coronavirus-idUSKCN21W2I8?il=0
# 78 https://www.reuters.com/article/us-health-coronavirus-tech-germany/german-tech-startups-plead-for-european-approach-to-corona-tracing-app-idUSKCN21W20F?il=0
# 79 https://www.reuters.com/article/us-gulf-vessel-attacks/ship-boarded-by-armed-men-in-gulf-of-oman-is-released-ukmto-idUSKCN21W2FP?il=0
# 80 https://www.reuters.com/article/us-health-coronavirus-britain-economy/uk-economy-could-shrink-by-the-most-in-300-years-in-2020-idUSKCN21W1EQ?il=0
# 81 https://www.reuters.com/article/us-health-coronavirus-debt-moratorium/top-creditors-to-suspend-poorest-countries-debt-payments-france-idUSKCN21W180?il=0
# 82 https://www.reuters.com/article/us-usa-banks-results/two-big-u-s-banks-offer-glum-outlook-for-coronavirus-recession-idUSKCN21W2N1?il=0
# 83 https://www.reuters.com/article/us-health-coronavirus-pakistan-mosques/pakistan-clerics-call-for-lifting-of-congregational-prayer-limits-idUSKCN21W2MF?il=0
# 84 https://www.reuters.com/article/us-health-coronavirus-chile-jails/chile-to-let-some-prisoners-out-of-jail-but-not-pinochet-era-human-rights-violators-idUSKCN21W2MZ?il=0
# 85 https://www.reuters.com/article/uk-health-coronavirus-iceland/time-for-a-haircut-iceland-to-begin-lifting-lockdown-in-may-idUSKCN21W2OI?il=0
# 86 https://www.reuters.com/article/us-global-oil-texas-opec/texas-hearing-on-oil-production-curbs-stirs-hornets-nest-idUSKCN21W225?il=0
# 87 https://www.reuters.com/article/us-health-coronavirus-usa-congress/republicans-warn-coronavirus-aid-program-running-out-of-cash-idUSKCN21W20O?il=0
# 88 https://www.reuters.com/article/us-health-coronavirus-mexico-hospital-ex/exclusive-nurses-at-mexico-hospital-hit-by-coronavirus-say-they-were-told-to-avoid-masks-idUSKCN21W1CT
# 89 https://www.reuters.com/article/us-health-coronavirus-england-casualties/uk-coronavirus-death-toll-could-be-far-higher-than-previously-shown-idUSKCN21W0YA
# 90 https://www.reuters.com/article/us-health-coronavirus-usa-protests/coronavirus-drives-u-s-political-protest-off-the-streets-and-into-online-forums-idUSKCN21W15D
# 91 https://www.reuters.com/article/us-hongkong-politics-judiciary-specialre/special-report-hong-kong-judges-battle-beijing-over-rule-of-law-as-pandemic-chills-protests-idUSKCN21W1C1
# 92 https://www.reuters.com/article/us-hongkong-politics/hong-kong-barristers-call-on-beijing-to-exercise-restraint-in-comments-idUSKCN21W1LL
# 93 https://www.reuters.com/article/us-health-coronavirus-usa-navajo/as-virus-tears-through-reservation-navajos-give-lifeline-to-elders-and-families-idUSKCN21W15X
# 94 https://www.reuters.com/article/us-global-oil-twitter/troll-no-more-energy-twitter-groups-big-short-on-shale-comes-good-idUSKCN21W0E7
# 95 https://www.reuters.com/article/us-health-coronavirus-wwe/florida-deems-wwe-essential-business-amid-coronavirus-outbreak-idUSKCN21W0AM
# 96 https://www.reuters.com/article/us-usa-banks-results/two-big-u-s-banks-offer-glum-outlook-for-coronavirus-recession-idUSKCN21W2N1
# 97 https://www.reuters.com/article/us-jpmorgan-results/jpmorgan-profit-dives-as-banks-brace-for-coronavirus-led-loan-defaults-idUSKCN21W1BW
# 98 https://www.reuters.com/article/us-spirit-aerosystm-results/spirit-expects-quarterly-loss-as-coronavirus-hits-plane-output-idUSKCN21W2J3
# 99 https://www.reuters.com/article/us-johnson-johnson-results/jj-sees-medical-devices-business-recovery-at-end-of-year-after-taking-coronavirus-hit-idUSKCN21W1AV
# 100 https://www.reuters.com/article/us-usa-election-obama/obama-endorses-democrat-bidens-2020-presidential-campaign-idUSKCN21W1YB
# 101 https://www.reuters.com/article/us-health-coronavirus-trump-ventilators/trump-to-announce-ventilator-loan-plan-to-fight-virus-idUSKCN21W2EZ
# 102 https://www.reuters.com/article/us-imf-worldbank-outlook/global-economy-in-2020-on-track-for-sharpest-downturn-since-1930s-imf-idUSKCN21W1MA
# 103 https://www.reuters.com/article/us-boeing-deliveries/boeing-737-max-cancellations-pile-up-during-production-halt-idUSKCN21W247
# 104 https://www.reuters.com/article/us-health-coronavirus/spain-austria-ease-curbs-but-who-warns-coronavirus-certainly-has-not-peaked-idUSKCN21W16E
# 105 https://www.reuters.com/news/picture/the-grim-toll-from-coronavirus-idUSRTX7CR2M
# 106 https://www.reuters.com/news/picture/top-photos-of-the-day-idUSRTX7CQE2
# 107 https://www.reuters.com/article/us-health-coronavirus-fed-bostic/fed-officials-see-risks-in-reopening-economy-too-soon-but-acknowledge-need-to-move-idUSKCN21W2ME
# 108 https://www.reuters.com/article/us-health-coronavirus-apple/apple-launches-site-to-show-how-coronavirus-lockdowns-affect-movement-idUSKCN21W2IN
# 109 https://www.reuters.com/article/us-imf-world-bank-debt-groups/faith-groups-afl-cio-urge-u-s-imf-g20-to-cancel-debt-for-poor-countries-idUSKCN21W2OT
# 110 https://www.reuters.com/article/us-health-coronavirus-britain-economy/uk-economy-could-shrink-by-the-most-in-300-years-in-2020-idUSKCN21W1EQ
# 111 https://www.reuters.com/article/us-health-coronavirus-debt-moratorium/top-creditors-to-suspend-poorest-countries-debt-payments-france-idUSKCN21W180
# 112 https://www.reuters.com/article/us-health-coronavirus-zimbabwe/zimbabwe-president-threatens-20-years-jail-over-fake-lockdown-statement-idUSKCN21W1H4
# 113 https://www.reuters.com/article/us-gulf-vessel-attacks/ship-boarded-by-armed-men-in-gulf-of-oman-is-released-ukmto-idUSKCN21W2FP
# 114 https://www.reuters.com/article/us-health-coronavirus-pakistan-mosques/pakistan-clerics-call-for-lifting-of-congregational-prayer-limits-idUSKCN21W2MF
# 115 https://www.reuters.com/article/us-health-coronavirus-tech-germany/german-tech-startups-plead-for-european-approach-to-corona-tracing-app-idUSKCN21W20F
# 116 https://www.reuters.com/article/us-health-coronavirus-tracing-explainer/explainer-how-smartphone-apps-can-help-contact-trace-the-new-coronavirus-idUSKCN21W2J6
# 117 https://www.reuters.com/article/us-autodesk-aurigo/autodesk-invests-in-public-infrastructure-software-firm-idUSKCN21W1QK
# 118 https://www.reuters.com/article/us-health-coronavirus-usa-cuomo/cuomo-says-if-trump-ordered-new-york-to-reopen-he-wouldnt-do-it-idUSKCN21W1L7
# 119 https://www.reuters.com/article/us-health-coronavirus-usa-congress/republicans-warn-coronavirus-aid-program-running-out-of-cash-idUSKCN21W20O
# 120 https://www.reuters.com/article/us-usa-election-absentee-voting-explaine/explainer-why-vote-by-mail-triggered-a-partisan-battle-ahead-of-novembers-election-idUSKCN21W162
# 121 https://www.reuters.com/article/us-renault-m-a-dongfeng/renault-quits-its-main-china-venture-after-weak-sales-idUSKCN21W0HB
# 122 https://www.reuters.com/article/us-sap-m-a/sap-explores-sale-of-digital-interconnect-business-bloomberg-idUSKCN21W1Q2
# 123 https://www.reuters.com/article/us-china-citic-securities-china-securiti/chinas-citic-securities-and-china-securities-both-say-not-aware-of-merger-talks-idUSKCN21W1DG
# 124 https://www.reuters.com/investigates/special-report/tips/
# 125 https://www.reuters.com/tools/podcasts
# 126 https://www.reuters.com/tools/mobile
# 127 https://www.reuters.com/article/us-reuters-editorial-leadership/reuters-editorial-leadership-idUSKBN1KE2SD
# 128 https://www.reuters.com/fact-check
# 129 https://www.reuters.com/info/disclaimer
# 130 https://www.reuters.com/advertising-guidelines
# 131 https://www.reuters.com/terms-of-use
# 132 https://www.reuters.com/article/us-health-coronavirus-companies-strategy/pandemic-survival-plans-u-s-businesses-scramble-to-conserve-cash-boost-liquidity-idUSKCN21W164
# 133 https://www.reuters.com/video/2020/04/14/tylenol-zyrtec-sales-boost-jjs-profit?videoId=711818563&videoChannel=5
# 134 https://www.reuters.com/video/2020/04/14/great-lockdown-to-shrink-global-economy?videoId=711818698&videoChannel=5
# 135 https://www.reuters.com/video/2020/04/14/renault-quits-main-china-venture-after-w?videoId=711815539&videoChannel=5
# 136 https://www.reuters.com/article/us-health-coronavirus-usa-airports/u-s-awards-airports-10-billion-in-grants-amid-travel-falloff-idUSKCN21W26K
# 137 https://www.reuters.com/article/us-health-coronavirus-usa-fauci/fauci-may-1-target-for-reopening-u-s-economy-overly-optimistic-ap-idUSKCN21W2FX
# 138 https://www.reuters.com/article/us-health-coronavirus-fiat-chrysler/fiat-chrysler-bolsters-cash-with-3-8-billion-syndicated-credit-idUSKCN21W2NN
# 139 https://www.reuters.com/article/us-tesla-stocks/tesla-surges-28-in-two-days-as-traders-look-beyond-coronavirus-disruption-idUSKCN21W2K3
# 140 https://www.reuters.com/news/archive/businessnews?view=page&page=2&pageSize=10
# 141 https://www.reuters.com/finance/markets/index?symbol=.SPX
# 142 https://www.reuters.com/finance/markets/index?symbol=.DJI
# 143 https://www.reuters.com/finance/markets/index?symbol=.FTSE
# 144 https://www.reuters.com/finance/markets/index?symbol=.N225
# 145 https://www.reuters.com/finance/currencies/quote?srcAmt=1&srcCurr=USD&destAmt=&destCurr=EUR
# 146 https://www.reuters.com/finance/currencies/quote?srcAmt=1&srcCurr=USD&destAmt=&destCurr=GBP
# 147 https://www.reuters.com/finance/currencies/quote?srcAmt=1&srcCurr=USD&destAmt=&destCurr=JPY
# 148 https://www.reuters.com/article/us-health-coronavirus-texas-abortion/us-appeals-court-blocks-texas-curbs-on-medication-abortion-idUSKCN21W076
# 149 https://www.reuters.com/article/us-people-jeffrey-epstein-new-york-times/harvard-professor-withdraws-new-york-times-defamation-lawsuit-over-jeffrey-epstein-story-idUSKCN21V1SU
# 150 https://www.reuters.com/article/us-usa-sec-bribery/u-s-sec-charges-ex-goldman-sachs-banker-for-bribes-to-ghana-officials-idUSKCN21W01I
# 151 https://www.reuters.com/article/us-health-coronavirus-texas-abortion/u-s-appeals-court-blocks-texas-curbs-on-medication-abortion-idUSKCN21W076
# 152 https://www.reuters.com/article/us-usa-drones/u-s-attorney-general-highlights-new-threat-to-security-from-drones-idUSKCN21V27F
# 153 https://www.reuters.com/article/us-health-coronavirus-usa-census/u-s-census-will-ramp-up-count-june-1-results-delayed-four-months-due-to-coronavirus-idUSKCN21V25A
# 154 https://www.reuters.com/article/us-chesapeake-energy-lawsuit-glass-mount/pipeline-operator-sues-chesapeake-energy-over-payment-dispute-idUSKCN21V249
# 155 https://www.reuters.com/article/us-usa-court-trump-finances/a-u-s-supreme-court-first-arguments-by-teleconference-including-major-one-involving-trump-idUSKCN21V1D4
# 156 https://www.reuters.com/news/archive/westLaw
# 157 https://www.reuters.com/article/ip-patent-alere/fed-circuit-orders-new-trial-in-abbott-drug-test-patent-case-idUSL2N2C118P
# 158 https://www.reuters.com/article/labor-uaw/uaws-clerical-error-did-not-violate-rights-of-ford-worker-who-resigned-6th-circuit-idUSL2N2C11VX
# 159 https://www.reuters.com/article/great-american-newton-covenant-church/massachusetts-breakaway-church-loses-insurance-coverage-appeal-idUSL2N2C11VZ
# 160 https://www.reuters.com/article/us-usa-court-insanity/u-s-supreme-court-lets-states-bar-insanity-defense-idUSKBN21A2E6
# 161 https://www.reuters.com/article/us-usa-court-comcast/u-s-supreme-court-tosses-ruling-that-revived-comedians-racial-bias-suit-against-comcast-idUSKBN21A2CI
# 162 https://www.reuters.com/article/us-usa-court-blackbeard/u-s-supreme-court-maroons-filmmaker-in-blackbeard-video-piracy-fight-idUSKBN21A2DE
# 163 https://www.reuters.com/article/us-health-coronavirus-usa-court/ginsburg-other-justices-healthy-as-u-s-supreme-court-adjusts-to-coronavirus-idUSKBN21736U
# 164 https://www.reuters.com/article/us-health-coronavirus-usa-court/u-s-supreme-court-postpones-arguments-amid-coronavirus-worries-idUSKBN2132FX
# 165 https://www.reuters.com/article/us-otc-ppp/federal-judge-small-businesses-do-not-have-right-to-sue-banks-over-ppp-lending-rules-idUSKCN21V20K
# 166 https://www.reuters.com/article/us-otc-essential/key-question-for-litigators-as-covid-19-rages-which-cases-are-essential-idUSKCN21R3FH
# 167 https://www.reuters.com/article/us-otc-covid19/for-supreme-court-covid-19-response-is-pretty-challenging-ex-roberts-clerk-idUSKCN21Q34L
# 168 https://www.reuters.com/news/archive/innovationNews
# 169 https://www.reuters.com/news/archive/technologyNews
# 170 https://www.reuters.com/news/archive/businessNews
# 171 https://www.reuters.com/article/us-finnair-china/finnair-says-plans-china-jv-with-juneyao-air-idUSKCN21W0QF
# 172 https://www.reuters.com/article/us-air-arabia-expansion/air-arabia-says-market-conditions-to-influence-new-airline-launch-but-no-delays-yet-idUSKCN21W0RD
# 173 https://www.reuters.com/article/us-cellnex-telecom-m-a-nos-sgps/cellnex-to-buy-noss-telecom-tower-business-in-375-million-euro-deal-idUSKCN21W0O8
# 174 https://www.reuters.com/article/us-health-coronavirus-poland-condor/polands-lot-pulls-out-of-deal-to-buy-german-airline-condor-idUSKCN21V1E0
# 175 https://www.reuters.com/article/us-hdfc-pboc-stake/china-central-bank-raises-stake-in-indias-hdfc-idUSKCN21V08Y
# 176 https://www.reuters.com/article/us-alnylam-pharms-investment-blackstone/alnylams-gene-silencing-efforts-get-2-billion-blackstone-backing-idUSKCN21V137
# 177 https://www.reuters.com/article/us-tegna-standardgeneral/ariel-investments-says-backs-tegna-in-fight-with-standard-general-idUSKCN21V2BK
# 178 https://www.reuters.com/article/us-vodafone-egypt-saudi-telecom-m-a/saudi-telecom-extends-vodafone-egypt-stake-purchase-process-by-90-days-idUSKCN21V0D2
# 179 https://www.reuters.com/article/us-health-coronavirus-antitrust-eu/eus-vestager-says-eu-nations-should-buy-stakes-to-block-chinese-takeovers-ft-idUSKCN21U0TI
# 180 https://www.reuters.com/article/us-health-coronavirus-banque-du-caire-ip/egypt-postpones-banque-du-caire-stake-sale-due-to-coronavirus-chairman-idUSKCN21U06E
# 181 https://www.reuters.com/article/us-tachosil-m-a-johnson-johnson/johnson-johnson-abandons-deal-for-takedas-tachosil-surgical-patch-idUSKCN21S1XG
# 182 https://www.reuters.com/article/us-prudential-finl-kb-financial-sale/kb-financial-group-acquires-prudentials-south-korean-unit-for-1-89-billion-idUSKCN21S0HW
# 183 https://www.reuters.com/article/us-exxon-mobil-lawsuit/california-developer-says-virus-an-act-of-god-sues-exxon-over-stalled-deal-idUSKCN21R0J1
# 184 https://www.reuters.com/article/us-health-coronavirus-psa-fiat/fiat-chrysler-and-peugeot-speed-up-work-to-close-the-merger-idUSKCN21R2SW
# 185 https://www.reuters.com/article/us-bilibili-m-a-sony/sony-invests-400-million-in-chinese-video-site-bilibili-idUSKCN21R202
# 186 https://www.reuters.com/article/us-avira-m-a-investcorp/investcorp-buys-german-cybersecurity-firm-avira-idUSKCN21R0SN
# 187 https://www.reuters.com/article/us-ukraine-chernobyl-fire/forest-fire-around-chernobyl-plant-put-out-ukraine-says-idUSKCN21W0VZ
# 188 https://www.reuters.com/article/us-health-coronavirus-france-space/space-scientists-use-covid-19-lockdown-as-dry-run-for-mars-mission-idUSKCN21W25S
# 189 https://www.reuters.com/article/us-usa-russia-arms/russia-says-its-ready-for-hypersonic-missile-talks-with-u-s-idUSKCN21W14C
# 190 https://www.reuters.com/article/us-health-coronavirus-bombardier/bombardier-to-resume-some-operations-in-uk-idUSKCN21W1VC
# 191 https://www.reuters.com/article/us-airbus-a350/delta-absorbs-order-for-10-airbus-a350-jets-cancelled-by-latam-sources-idUSKCN21W1PU
# 192 https://www.reuters.com/article/us-health-coronravirus-wizz-air-hldgs-ce/wizz-air-not-considering-plane-deferrals-sees-growth-returning-in-2022-ceo-idUSKCN21W1AZ
# 193 https://www.reuters.com/article/us-northkorea-missiles/north-korea-test-fires-multiple-short-range-anti-ship-missiles-idUSKCN21W0FS
# 194 https://www.reuters.com/news/archive/aerospace-defense?view=page&page=2&pageSize=10
# 195 https://www.reuters.com/video/2018/07/07/why-your-plane-might-be-hackers-next-tar?videoId=446527693&videoChannel=118264
# 196 https://www.reuters.com/video/2018/07/17/rising-oil-price-spurs-jet-buying-bonanz?videoId=446212418&videoChannel=118264
# 197 https://www.reuters.com/video/2018/07/16/qatar-airways-ceo-shrugs-off-blockade-co?videoId=445921270&videoChannel=118264
# 198 https://www.reuters.com/article/us-wells-fargo-results/wells-fargo-profit-decimated-as-coronavirus-led-loan-defaults-loom-idUSKCN21W1JW
# 199 https://www.reuters.com/article/us-global-oil-opec-goldman/goldman-sachs-still-sees-crude-prices-falling-after-opec-deal-idUSKCN21V07H
# 200 https://www.reuters.com/article/us-jp-morgan-mortgages-credit-exclusive/exclusive-jpmorgan-chase-to-raise-mortgage-borrowing-standards-as-economic-outlook-darkens-idUSKCN21T0VU
# 201 https://www.reuters.com/article/us-health-coronavirus-morganstanley/morgan-stanley-ceo-diagnosed-with-coronavirus-in-march-since-recovered-bank-video-idUSKCN21R22V
# 202 https://www.reuters.com/article/us-jp-morgan-loans-saudi-emirates-exclus/exclusive-jpmorgan-looking-to-offload-saudi-and-uae-sovereign-fund-loans-sources-idUSKCN21R1WA
# 203 https://www.reuters.com/article/us-healthswiss-banks/ubs-and-credit-suisse-bow-to-regulator-pressure-on-dividends-idUSKCN21R0FW
# 204 https://www.reuters.com/article/uk-health-coronavirus-wells-fargo/fed-modifying-asset-cap-so-wells-fargo-can-make-more-small-business-loans-idUSKCN21Q2E1
# 205 https://www.reuters.com/news/archive/banks?view=page&page=2&pageSize=10
# 206 https://www.reuters.com/article/us-health-coronavirus-gm/gm-begins-mass-production-of-ventilators-for-u-s-government-idUSKCN21W2OK
# 207 https://www.reuters.com/article/us-health-coronavirus-honda-mexico/honda-extends-mexico-plant-suspensions-to-april-30-due-to-coronavirus-idUSKCN21W2F7
# 208 https://www.reuters.com/article/us-health-coronavirus-finance-breakingvi/breakingviews-corona-capital-bank-credit-lines-renault-idUSKCN21W265
# 209 https://www.reuters.com/article/us-health-coronavirus-czech-autos/hyundai-first-to-restart-czech-production-others-still-shut-idUSKCN21W1VQ
# 210 https://www.reuters.com/article/us-health-coronavirus-hyundai-motor/hyundai-to-provide-covid-19-tests-drive-through-testing-support-in-u-s-idUSKCN21W1R9
# 211 https://www.reuters.com/article/us-health-coronavirus-toyota/toyota-plans-limited-operations-in-france-poland-from-april-22-idUSKCN21W14D
# 212 https://www.reuters.com/article/us-health-coronavirus-valeo/car-parts-group-valeo-drops-2020-targets-gets-1-billion-euros-of-new-credit-lines-idUSKCN21W0K2
# 213 https://www.reuters.com/article/us-valero-energy-outlook/valero-warns-of-up-to-2-1-billion-first-quarter-loss-on-demand-drop-idUSKCN21V1WF
# 214 https://www.reuters.com/article/us-health-coronavirus-finance-breakingvi/breakingviews-corona-capital-oil-cheerleading-mortgaging-ford-idUSKCN21V22O
# 215 https://www.reuters.com/article/us-health-coronavirus-insurance-auto-fac/factbox-insurers-return-part-of-auto-premiums-as-coronavirus-cuts-driving-idUSKCN21R34W
# 216 https://www.reuters.com/article/us-health-coronavirus-ford/ford-making-masks-to-protect-workers-against-covid-19-idUSKCN21V1RC
# 217 https://www.reuters.com/article/us-health-coronavirus-insurance-californ/california-insurance-commissioner-orders-relief-for-customers-idUSKCN21V1SY
# 218 https://www.reuters.com/article/us-health-coronavirius-volkswagen/volkswagen-offers-cars-for-relief-efforts-in-u-s-virus-hit-regions-idUSKCN21V11A
# 219 https://www.reuters.com/article/us-ford-motor-results/ford-expects-coronavirus-shutdown-to-cause-600-million-quarterly-loss-idUSKCN21V1AE
# 220 https://www.reuters.com/article/us-health-coronavirus-brazil-autos/toyota-joins-gm-in-suspending-auto-production-in-brazil-until-june-idUSKCN21V1C9
# 221 https://www.reuters.com/article/us-health-coronavirus-gm-brazil/gm-plans-to-extend-shutdown-of-brazil-auto-production-by-60-days-idUSKCN21R3D8
# 222 https://www.reuters.com/article/us-health-coronavirus-china-business/chinese-manufacturing-recovering-but-demand-now-a-concern-eu-business-group-idUSKCN21V10C
# 223 https://www.reuters.com/news/archive/autos-upclose?view=page&page=2&pageSize=10
# 224 https://www.reuters.com/article/us-health-coronavirus-russia-cases/russias-coronavirus-cases-surpass-20000-in-record-daily-rise-idUSKCN21W0QR
# 225 https://www.reuters.com/article/health-coronavirus-gm/update-1-gm-begins-mass-production-of-ventilators-for-u-s-government-idUSL3N2C242I
# 226 https://www.reuters.com/article/health-coronavirus-russia-cases/update-1-moscows-lockdown-permit-system-fuels-surveillance-fears-idUSL5N2C24DD
# 227 https://www.reuters.com/article/safrica-saa/update-1-south-african-government-wont-give-saa-more-funds-rescue-team-idUSL5N2C2644
# 228 https://www.reuters.com/summit/Investment20
# 229 https://www.reuters.com/article/us-investment-summit-protests/investors-wary-as-social-unrest-spreads-from-hong-kong-to-santiago-idUSKBN1XL0J6
# 230 https://www.reuters.com/finance/summits/past
# 231 https://www.reuters.com/summit/Investment19
# 232 https://www.reuters.com/summit/Commodities18
# 233 https://www.reuters.com/summit/Investment18
# 234 https://www.reuters.com/summit/Cybersecurity17
# 235 https://www.reuters.com/summit/Commodities17
# 236 https://www.reuters.com/summit/FinancialRegulation17
# 237 https://www.reuters.com/summit/Russia17
# 238 https://www.reuters.com/summit/LatinAmerica17
# 239 https://www.reuters.com/summit/CentralEasternEuropeInvestment17
# 240 https://www.reuters.com/article/us-health-coronavirus-climatechange-reco/european-politicians-ceos-lawmakers-urge-green-coronavirus-recovery-idUSKCN21W0F2
# 241 https://www.reuters.com/article/us-europe-windfarm/new-wind-farm-financing-in-europe-to-face-delays-in-2020-report-idUSKBN21P16V
# 242 https://www.reuters.com/article/us-health-coronavirus-funds-esg/graphic-sustainable-funds-a-safer-harbour-in-coronavirus-market-meltdown-idUSKBN21O1AF
# 243 https://www.reuters.com/article/us-health-coronavirus-emissions/coronavirus-could-trigger-biggest-fall-in-carbon-emissions-since-world-war-two-idUSKBN21L0HL
# 244 https://www.reuters.com/article/us-coal-japan-mizuho-climatechange/investors-line-up-against-mizuho-support-for-coal-idUSKBN21O12C
# 245 https://www.reuters.com/article/us-health-coronavirus-eurozone-breakingv/breakingviews-dixon-reports-of-euros-death-greatly-exaggerated-idUSKCN21W2P3
# 246 https://www.reuters.com/video/?chan=9hh451f6
# 247 https://www.reuters.com/video/2020/01/20/chipsafer-revolutionizing-ranching-one-t?videoId=663728025&videoChannel=118285
# 248 https://www.reuters.com/video/2020/01/15/uae-to-open-first-nuclear-power-plant?videoId=660084393&videoChannel=118285
# 249 https://www.reuters.com/video/2020/01/15/we-are-moving-people-away-from-the-coast?videoId=660064557&videoChannel=118285
# 250 https://www.reuters.com/subjects/sustainable-business/environmental-impact
# 251 https://www.reuters.com/subjects/sustainable-business/workplace-equality
# 252 https://www.reuters.com/article/us-soccer-spain-women/spains-top-flight-women-soccer-players-secure-collective-wage-deal-idUSKCN20G0KJ
# 253 https://www.reuters.com/article/us-britain-diversity-succession/uk-corporate-governance-watchdog-wants-more-progress-on-women-on-boards-idUSKBN2090E8
# 254 https://www.reuters.com/article/us-wells-fargo-harassment/wells-fargo-ends-forced-arbitration-for-sexual-harassment-claims-idUSKBN2062J4
# 255 https://www.reuters.com/subjects/sustainable-business/tech-trust
# 256 https://www.reuters.com/article/us-twitter-security/twitter-tests-labels-community-moderation-for-lies-by-public-figures-idUSKBN20E2UR
# 257 https://www.reuters.com/article/us-clearview-ai-canada/facial-recognition-company-clearview-ai-probed-by-canada-privacy-agencies-idUSKBN20F2I3
# 258 https://www.reuters.com/article/us-mgm-resorts-intl-cyber-lawsuit/mgm-resorts-sued-over-data-breach-that-possibly-involved-10-6-million-guests-idUSKCN20G062
# 259 https://www.reuters.com/subjects/sustainable-business/responsible-investing
# 260 https://www.reuters.com/article/us-health-coronavirus-climate-analysis/for-richer-or-poorer-coronavirus-cheap-oil-test-climate-vows-idUSKBN20Z0PD
# 261 https://www.reuters.com/article/us-climatechange-ecb-lagarde/banks-must-step-up-climate-risk-disclosures-lagarde-says-idUSKCN20L190
# 262 https://www.reuters.com/article/us-eu-markets-climatechange/esg-investments-could-reduce-focus-on-quick-profits-eu-watchdog-idUSKBN20D2BZ
# 263 https://www.reuters.com/article/us-eu-carbon-data/eu-carbon-market-emissions-excluding-aviation-fell-8-7-in-2019-idUSKBN21J604
# 264 https://www.reuters.com/article/us-climagechange-barclays/barclays-sets-2050-net-zero-carbon-goal-after-investor-pressure-idUSKBN21H0Z8
# 265 https://www.reuters.com/article/us-fortum-uniper-finnish-government/finnish-government-pushes-fortum-to-strive-for-carbon-neutrality-idUSKBN21H2LJ
# 266 https://www.reuters.com/article/us-hydrogen-investment-study/carbon-free-hydrogen-production-needs-multi-billion-dollar-subsidies-to-make-it-cost-effective-research-idUSKBN21H1SC
# 267 https://www.reuters.com/article/us-equinor-lobbying/equinor-to-quit-u-s-lobby-group-over-climate-policy-idUSKBN21E2KU
# 268 https://www.reuters.com/news/archive/esgnews?view=page&page=2&pageSize=10
# 269 https://www.reuters.com/investigates/section/ocean-shock/
# 270 https://www.reuters.com/article/us-health-coronavirus-videoconferencing/cats-pjs-alien-eyes-unwelcome-as-work-video-calling-boom-prompts-new-etiquette-idUSKBN2143Y7
# 271 https://www.reuters.com/video/world-at-work
# 272 https://www.reuters.com/video/2019/03/28/uniformly-stylish-chefs-nurses-boast-new?videoId=533189236&videoChannel=118267
# 273 https://www.reuters.com/video/2019/03/05/let-the-robots-do-your-dirty-work?videoId=522322194&videoChannel=118267
# 274 https://www.reuters.com/video/2019/01/16/diversity-bottom-line-drive-push-for-fem?videoId=504320386&videoChannel=118267
# 275 https://www.reuters.com/article/us-health-coronavirus-banks-anxiety/wall-street-tempers-begin-to-flare-over-coronavirus-work-from-home-policy-idUSKBN2150HR
# 276 https://www.reuters.com/article/us-health-coronavirus-cloud/coronavirus-work-from-home-push-means-long-nights-employee-health-checks-for-cloud-firms-idUSKBN21031M
# 277 https://www.reuters.com/article/us-japan-companies-wages/japan-inc-wary-about-wage-hikes-as-abenomics-sputters-reuters-poll-idUSKBN20C01E
# 278 https://www.reuters.com/article/us-world-work-intelisrael/intel-bets-on-smart-buildings-in-israel-to-attract-tech-talent-idUSKBN1ZZ0G0
# 279 https://www.reuters.com/article/us-world-work-vrtraining/to-train-more-workers-companies-turn-to-virtual-reality-idUSKBN1ZL1AN
# 280 https://www.reuters.com/article/us-southkorea-artificial-intelligence-jo/smile-with-your-eyes-how-to-beat-south-koreas-ai-hiring-bots-and-land-a-job-idUSKBN1ZC022
# 281 https://www.reuters.com/article/us-world-work-softskills/how-can-generation-z-compete-with-robots-focus-on-the-human-touch-idUSKBN1YK0CM
# 282 https://www.reuters.com/article/us-japan-harassment-appearance/specs-on-heels-off-japanese-activists-urge-changes-to-anti-harassment-code-idUSKBN1Y70QT
# 283 https://www.reuters.com/article/us-world-work-givingtuesday/your-money-on-givingtuesday-companies-turbocharge-holiday-giving-efforts-idUSKBN1Y12F1
# 284 https://www.reuters.com/article/us-world-work-vetrepreneurs/helping-veterans-develop-business-skills-as-entrepreneurs-idUSKBN1XL2LS
# 285 https://www.reuters.com/video/2020/04/14/shares-gain-on-signs-chinas-trade-slump?videoId=711806329&newsChannel=ousivMolt
# 286 https://www.reuters.com/article/usa-bonds/treasuries-yields-narrowly-mixed-market-optimistic-about-virus-outlook-idUSL2N2C213J
# 287 https://www.reuters.com/article/health-coronavirus-fed-bostic/wrapup-1-fed-officials-see-risks-in-reopening-economy-too-soon-but-acknowledge-need-to-move-idUSL2N2C21D3
# 288 https://www.reuters.com/article/imf-world-bank-debt-groups/faith-groups-afl-cio-urge-u-s-imf-g20-to-cancel-debt-for-poor-countries-idUSL2N2C21G6
# 289 https://www.reuters.com/article/health-coronavirus-britain-economy/update-4-uk-economy-could-shrink-by-the-most-in-300-years-in-2020-idUSL5N2C23FU
# 290 https://www.reuters.com/article/global-oil-texas-opec/update-3-texas-hearing-on-oil-production-curbs-stirs-hornets-nest-idUSL2N2C20WU
# 291 https://www.reuters.com/article/intercement-debt/update-2-brazils-intercement-delays-local-bond-payment-by-90-days-idUSL2N2C2143
# 292 https://www.reuters.com/article/health-coronavirus-usa-congress/update-3-u-s-republicans-warn-coronavirus-aid-program-running-out-of-cash-idUSL2N2C20RK
# 293 https://www.reuters.com/article/health-coronavirus-england-casualties/update-5-uk-coronavirus-death-toll-could-be-far-higher-than-previously-shown-idUSL5N2C2235
# 294 https://www.reuters.com/article/usa-banks-results/wrapup-1-two-big-u-s-banks-offer-glum-outlook-for-coronavirus-recession-idUSL2N2C2107
# 295 https://www.reuters.com/news/archive/marketsNews?view=page&page=2&pageSize=10
# 296 https://www.reuters.com/article/us-europe-stocks/european-shares-rise-on-china-trade-data-easing-coronavirus-worries-idUSKCN21W0OI
# 297 https://www.reuters.com/article/europe-stocks/update-2-european-shares-rise-on-china-trade-data-easing-coronavirus-worries-idUSL3N2C21YQ
# 298 https://www.reuters.com/article/europe-stocks/european-shares-jump-on-china-trade-data-coronavirus-hopes-idUSL3N2C21WG
# 299 https://www.reuters.com/article/us-europe-stocks/european-shares-post-best-week-since-2011-focus-on-eu-stimulus-idUSKCN21R0WO
# 300 https://www.reuters.com/article/europe-stocks/update-2-european-shares-post-best-week-since-2011-focus-on-eu-stimulus-idUSL3N2BX2T7
# 301 https://www.reuters.com/article/europe-stocks/update-1-european-shares-gain-on-hopes-pandemic-could-soon-ease-idUSL5N2BX2WQ
# 302 https://www.reuters.com/article/europe-stocks/european-shares-jump-on-hopes-of-coronavirus-progress-idUSL3N2BX1ZM
# 303 https://www.reuters.com/article/us-europe-stocks/european-shares-inch-up-all-eyes-on-euro-zone-fiscal-package-idUSKBN21Q0RX
# 304 https://www.reuters.com/article/europe-stocks/update-2-european-shares-inch-up-all-eyes-on-euro-zone-fiscal-package-idUSL4N2BW1WL
# 305 https://www.reuters.com/article/us-europe-stocks-results/europe-inc-profit-expectations-plunge-amid-lockdowns-idUSKBN21Q0YV
# 306 https://www.reuters.com/news/archive/europe-stocks?view=page&page=2&pageSize=10
# 307 https://www.reuters.com/article/global-markets/global-markets-stocks-gain-on-china-trade-data-easing-pandemic-worries-idUSL5N2C24KS
# 308 https://www.reuters.com/article/global-forex/forex-dollar-slips-as-risk-appetite-returns-to-market-idUSL5N2C24QE
# 309 https://www.reuters.com/article/health-coronavirus-economy/refile-rpt-graphic-alphabet-soup-how-will-post-virus-economic-recovery-shape-up-idUSL5N2BX582
# 310 https://www.reuters.com/article/global-markets/global-markets-stocks-gain-on-china-trade-data-easing-pandemic-worries-idUSL5N2C23JM
# 311 https://www.reuters.com/article/global-forex/forex-dollar-slips-as-chinese-data-improves-idUSL5N2C2308
# 312 https://www.reuters.com/article/emerging-markets/emerging-markets-stocks-near-1-month-high-on-chinese-trade-data-fx-muted-idUSL5N2C21VQ
# 313 https://www.reuters.com/article/global-forex/forex-dollar-slips-as-chinese-data-improves-idUSL5N2C21VX
# 314 https://www.reuters.com/article/global-markets/refile-global-markets-stocks-rise-on-china-trade-data-easing-pandemic-fears-idUSL5N2C21PM
# 315 https://www.reuters.com/article/markets-europe-view/morning-bid-seeking-an-exit-idUSL5N2C21OC
# 316 https://www.reuters.com/article/japan-stocks/massive-short-squeeze-sends-nikkei-to-1-month-high-softbank-group-jumps-idUSL3N2C21YF
# 317 https://www.reuters.com/news/archive/tokyoMktRpt?view=page&page=2&pageSize=10
# 318 https://www.reuters.com/finance/markets/index?symbol=.IXIC
# 319 https://www.reuters.com/article/usa-stocks/us-stocks-wall-st-surges-on-hopes-of-lockdown-easing-jpmorgan-kicks-off-earnings-idUSL3N2C23ZB
# 320 https://www.reuters.com/finance/markets/index?symbol=.TRXFLDUSP
# 321 https://www.reuters.com/finance/markets/index?symbol=.TRXFLDCAP
# 322 https://www.reuters.com/finance/markets/index?symbol=.GSPTSE
# 323 https://www.reuters.com/finance/markets/index?symbol=.XAX
# 324 https://www.reuters.com/finance/markets/index?symbol=.MXX
# 325 https://www.reuters.com/finance/markets/upgrades
# 326 https://www.reuters.com/finance/stocks/overview?symbol=BBGI.OQ
# 327 https://www.reuters.com/finance/stocks/overview?symbol=UFI.N
# 328 https://www.reuters.com/finance/stocks/overview?symbol=FFG.N
# 329 https://www.reuters.com/finance/markets/downgrades
# 330 https://www.reuters.com/finance/stocks/overview?symbol=KNL.N
# 331 https://www.reuters.com/finance/stocks/overview?symbol=MLHR.OQ
# 332 https://www.reuters.com/finance/stocks/overview?symbol=GNC.N
# 333 https://www.reuters.com/finance/markets/ /instagram.com/reuters/
# 334 https://www.reuters.com/article/europe-stocks/european-shares-retreat-after-two-day-rally-as-tesco-slumps-idUSL4N2BW1TA
# 335 https://www.reuters.com/article/europe-stocks/update-2-european-shares-at-1-month-high-on-hopes-coronavirus-crisis-may-be-easing-idUSL4N2BV256
# 336 https://www.reuters.com/article/europe-stocks/european-shares-climb-as-coronavirus-cases-slow-idUSL4N2BV1YQ
# 337 https://www.reuters.com/article/europe-stocks/update-4-european-shares-jump-as-coronavirus-deaths-slow-germany-up-almost-6-idUSL4N2BU1DJ
# 338 https://www.reuters.com/finance/markets/index?symbol=.TRXFLDGBP
# 339 https://www.reuters.com/finance/markets/index?symbol=.TRXFLDDEP
# 340 https://www.reuters.com/finance/markets/index?symbol=.TRXFLDFRP
# 341 https://www.reuters.com/finance/markets/index?symbol=.FTMC
# 342 https://www.reuters.com/finance/markets/index?symbol=.FTT1X
# 343 https://www.reuters.com/finance/markets/index?symbol=.GDAXI
# 344 https://www.reuters.com/finance/markets/index?symbol=.FCHI
# 345 https://www.reuters.com/finance/markets/index?symbol=.SSMI
# 346 https://www.reuters.com/finance/markets/index?symbol=.SMSI
# 347 https://www.reuters.com/finance/markets/index?symbol=.OMXSPI
# 348 https://www.reuters.com/finance/markets/index?symbol=.OMXHPI
# 349 https://www.reuters.com/finance/markets/index?symbol=.OMXC20
# 350 https://www.reuters.com/finance/markets/index?symbol=.OSEAX
# 351 https://www.reuters.com/finance/markets/index?symbol=.ISEQ
# 352 https://www.reuters.com/finance/markets/index?symbol=.BFX
# 353 https://www.reuters.com/finance/markets/index?symbol=.AEX
# 354 https://www.reuters.com/finance/markets/index?symbol=.IBEX
# 355 https://www.reuters.com/finance/markets/index?symbol=.BVLG
# 356 https://www.reuters.com/finance/markets/index?symbol=.STOXX50
# 357 https://www.reuters.com/news/archive/londonMktRpt
# 358 https://www.reuters.com/article/britain-stocks-factors/update-1-uk-stocks-factors-to-watch-on-april-9-idUSL3N2BX1WR
# 359 https://www.reuters.com/article/britain-stocks-factors/uk-stocks-factors-to-watch-on-april-9-idUSL3N2BX1H6
# 360 https://www.reuters.com/article/britain-stocks-factors/uk-stocks-factors-to-watch-on-april-8-idUSL4N2BW1FP
# 361 https://www.reuters.com/news/archive/swissMktRpt
# 362 https://www.reuters.com/article/mch-group-baselworld/update-1-rolex-joins-baselworld-defections-that-cast-doubt-on-watch-fairs-future-idUSL5N2C265R
# 363 https://www.reuters.com/article/brief-mch-group-ag-says-considering-futu/brief-mch-group-ag-says-considering-future-of-baselworld-after-rolex-others-exit-idUSFWN2C215C
# 364 https://www.reuters.com/article/flughafn-zuerich-flights/zurich-airport-flights-down-95-in-april-as-coronavirus-grounds-travel-idUSFWN2C214R
# 365 https://www.reuters.com/article/mch-group-baselworld/rolex-joins-leading-watchmakers-withdrawing-from-baselworld-fair-idUSL5N2C250S
# 366 https://www.reuters.com/article/bolsaasia-fecha/bolsa-sia-mercado-da-china-fecha-em-alta-com-dados-comerciais-melhores-que-o-esperado-idUSL2N2C208Q
# 367 https://www.reuters.com/article/southeast-asia-stocks/se-asia-stocks-rise-as-china-data-tops-expectations-philippines-surges-3-idUSL3N2C22J4
# 368 https://www.reuters.com/article/china-stocks-hongkong-close/hong-kong-shares-end-higher-as-china-trade-data-lifts-sentiment-idUSAZN18NU00
# 369 https://www.reuters.com/article/china-stocks-close/chinese-shares-end-higher-on-better-than-expected-trade-data-idUSAPN0DQ8P1
# 370 https://www.reuters.com/article/australia-stocks-close/australia-shares-end-at-1-month-high-on-china-trade-data-idUSL3N2C21UP
# 371 https://www.reuters.com/article/softbank-group-stocks/update-2-softbank-record-loss-estimate-renews-asset-sale-focus-idUSL3N2C201U
# 372 https://www.reuters.com/article/japan-insurer-fukoku-life-ins/update-1-japans-fukoku-life-plans-to-boost-stocks-foreign-bonds-without-fx-hedge-idUSL3N2C21J5
# 373 https://www.reuters.com/article/china-stocks-midday/china-hong-kong-stocks-rise-on-better-than-expected-trade-data-idUSL3N2C21F4
# 374 https://www.reuters.com/article/japan-insurer-fukoku-life-ins/japans-fukoku-life-plans-to-boost-stocks-foreign-bond-without-fx-hedge-in-current-financial-year-idUSL3N2C21FC
# 375 https://www.reuters.com/article/japan-stocks/nikkei-bounces-back-as-semiconductor-related-shares-gain-idUSL3N2C212Y
# 376 https://www.reuters.com/article/southeast-asia-stocks/se-asia-stocks-climb-in-thin-trade-on-signs-of-pandemic-peaking-idUSL3N2C2101
# 377 https://www.reuters.com/article/australia-stocks-midday/gold-stocks-lift-australia-shares-to-1-month-high-corporate-earnings-loom-idUSL3N2C13NN
# 378 https://www.reuters.com/article/softbank-group-stocks/softbank-shares-untraded-after-estimating-historic-loss-idUSL3N2C2009
# 379 https://www.reuters.com/article/australia-stocks-morning/australia-shares-set-to-rise-at-open-nz-gains-idUSL3N2C130E
# 380 https://www.reuters.com/finance/markets/asia?view=page&page=2&pageSize=10
# 381 https://www.reuters.com/finance/markets/index?symbol=.TRXFLDJPP
# 382 https://www.reuters.com/finance/markets/index?symbol=.TRXFLDHKP
# 383 https://www.reuters.com/finance/markets/index?symbol=.TRXFLDINP
# 384 https://www.reuters.com/finance/markets/index?symbol=.HSI
# 385 https://www.reuters.com/finance/markets/index?symbol=.AORD
# 386 https://www.reuters.com/finance/markets/index?symbol=.KS11
# 387 https://www.reuters.com/finance/markets/index?symbol=.SETI
# 388 https://www.reuters.com/finance/markets/index?symbol=.JKSE
# 389 https://www.reuters.com/finance/markets/index?symbol=.PSI
# 390 https://www.reuters.com/finance/markets/index?symbol=.SSEC
# 391 https://www.reuters.com/finance/markets/index?symbol=.BSESN
# 392 https://www.reuters.com/finance/markets/index?symbol=.FTFBMKLCI
# 393 https://www.reuters.com/finance/markets/index?symbol=.HNX30
# 394 https://www.reuters.com/finance/markets/index?symbol=.TRXFLDEUPU
# 395 https://www.reuters.com/sectors/energy
# 396 https://www.reuters.com/sectors/industries/overview?industryCode=193
# 397 https://www.reuters.com/sectors/industries/overview?industryCode=6
# 398 https://www.reuters.com/sectors/industries/overview?industryCode=190
# 399 https://www.reuters.com/sectors/basic-materials
# 400 https://www.reuters.com/sectors/industries/overview?industryCode=18
# 401 https://www.reuters.com/sectors/industries/overview?industryCode=23
# 402 https://www.reuters.com/sectors/industries/overview?industryCode=26
# 403 https://www.reuters.com/sectors/industrials
# 404 https://www.reuters.com/sectors/industries/overview?industryCode=39
# 405 https://www.reuters.com/sectors/industries/overview?industryCode=46
# 406 https://www.reuters.com/sectors/cyclicals
# 407 https://www.reuters.com/sectors/industries/overview?industryCode=72
# 408 https://www.reuters.com/sectors/industries/overview?industryCode=77
# 409 https://www.reuters.com/sectors/industries/overview?industryCode=78
# 410 https://www.reuters.com/sectors/non-cyclicals
# 411 https://www.reuters.com/sectors/industries/overview?industryCode=109
# 412 https://www.reuters.com/sectors/industries/overview?industryCode=120
# 413 https://www.reuters.com/sectors/industries/overview?industryCode=124
# 414 https://www.reuters.com/sectors/financials
# 415 https://www.reuters.com/sectors/industries/overview?industryCode=128
# 416 https://www.reuters.com/sectors/industries/overview?industryCode=209
# 417 https://www.reuters.com/sectors/industries/overview?industryCode=138
# 418 https://www.reuters.com/sectors/healthcare
# 419 https://www.reuters.com/sectors/industries/overview?industryCode=158
# 420 https://www.reuters.com/sectors/industries/overview?industryCode=159
# 421 https://www.reuters.com/sectors/technology
# 422 https://www.reuters.com/sectors/industries/overview?industryCode=164
# 423 https://www.reuters.com/sectors/industries/overview?industryCode=169
# 424 https://www.reuters.com/sectors/industries/overview?industryCode=173
# 425 https://www.reuters.com/sectors/telecom
# 426 https://www.reuters.com/sectors/industries/overview?industryCode=178
# 427 https://www.reuters.com/sectors/industries/overview?industryCode=179
# 428 https://www.reuters.com/sectors/utilities
# 429 https://www.reuters.com/sectors/industries/overview?industryCode=183
# 430 https://www.reuters.com/sectors/industries/overview?industryCode=185
# 431 https://www.reuters.com/sectors/industries/overview?industryCode=187
# 432 https://www.reuters.com/quote/.DJI
# 433 https://www.reuters.com/quote/.IXIC
# 434 https://www.reuters.com/quote/.NYA
# 435 https://www.reuters.com/quote/.SPX
# 436 https://www.reuters.com/quote/.GSPTSE
# 437 https://www.reuters.com/quote/.FTSE
# 438 https://www.reuters.com/quote/.STOXX50E
# 439 https://www.reuters.com/quote/.GDAXI
# 440 https://www.reuters.com/quote/.FCHI
# 441 https://www.reuters.com/quote/.IBEX
# 442 https://www.reuters.com/quote/.N225
# 443 https://www.reuters.com/quote/.HSI
# 444 https://www.reuters.com/quote/.AORD
# 445 https://www.reuters.com/quote/.SSEC
# 446 https://www.reuters.com/quote/.BSESN
# 447 https://www.reuters.com/quote/SPc1
# 448 https://www.reuters.com/quote/NQc1
# 449 https://www.reuters.com/quote/FFIc1
# 450 https://www.reuters.com/quote/FCEc1
# 451 https://www.reuters.com/quote/FDXc1
# 452 https://www.reuters.com/quote/NKc1
# 453 https://www.reuters.com/quote/JNIc1
# 454 https://www.reuters.com/article/us-global-oil-texas-opec/texas-hearing-on-oil-production-curbs-stirs-hornets-nest-idUSKCN21W225
# 455 https://www.reuters.com/article/safrica-saa-funding/s-africa-govt-wont-give-more-funds-for-saa-rescue-administrators-idUSL5N2C262N
# 456 https://www.reuters.com/article/brazil-economy-state-aid/brazil-govt-proposes-40-bln-reais-transfer-to-states-idUSS0N2BG01S
# 457 https://www.reuters.com/article/safrica-saa/south-african-ministry-says-still-exploring-options-for-struggling-saa-idUSJ8N2A600Y
# 458 https://www.reuters.com/article/health-coronavirus-britain-borrowing/uks-sunak-says-growth-best-way-to-erode-coronavirus-debt-mountain-idUSS8N2BU03K
# 459 https://www.reuters.com/article/us-ireland-politics/historic-irish-rivals-strike-government-deal-seek-third-partner-idUSKCN21W2AH
# 460 https://www.reuters.com/article/health-coronavirus-fed-evans/feds-evans-says-too-soon-u-s-reopening-could-prolong-downturn-idUSU5N28101R
# 461 https://www.reuters.com/article/us-imf-worldbank-debt/global-creditors-agree-debt-relief-for-poor-countries-hit-by-pandemic-idUSKCN21W2HE
# 462 https://www.reuters.com/article/us-health-coronavirus-britain-data/uk-working-to-add-non-hospital-virus-deaths-to-daily-data-health-official-idUSKCN21W2G1
# 463 https://www.reuters.com/article/health-coronavirus-safrica-economy/update-3-south-africa-rules-out-imf-programme-despite-budget-woes-idUSL5N2C23JG
# 464 https://www.reuters.com/article/us-health-coronavirus-funds/u-s-funds-that-beat-market-plunge-seek-recession-proof-stocks-idUSKCN21W2GR
# ...
# 1186 https://www.reuters.com/article/us-health-coronavirus-russia-art/isolation-art-recreate-masterworks-with-cabbage-lentils-and-socks-idUSKBN21Q263
# 1187 https://www.reuters.com/article/us-health-coronavirus-swiss-graffiti/swiss-street-artist-pays-tribute-to-unsung-coronavirus-heroes-idUSKBN21O2MN
# 1188 https://www.reuters.com/article/us-netherlands-museum-van-gogh/van-gogh-painting-stolen-from-dutch-museum-closed-by-coronavirus-idUSKBN21H23M
# 1189 https://www.reuters.com/article/us-health-coronavirus-britain-rate/some-plateauing-of-london-coronavirus-outbreak-uk-says-idUSKBN21M0MQ
# 1190 https://www.reuters.com/article/us-health-coronavirus-russia-bolshoi/russias-bolshoi-theater-goes-online-as-coronavirus-curbs-public-life-idUSKBN21E35D
# 1191 https://www.reuters.com/article/us-health-coronavirus-senegal-graffiti/senegals-graffiti-artists-join-fight-against-coronavirus-idUSKBN21E1Q5
# 1192 https://www.reuters.com/article/us-britain-art-titian/after-400-years-london-show-reunites-six-masterpieces-by-titian-idUSKBN20Z2ED
# 1193 https://www.reuters.com/article/us-health-coronavirus-streaming/facebook-lowers-video-quality-in-latin-america-following-europe-idUSKBN21B02M
# 1194 https://www.reuters.com/article/us-health-coronavirus-netherlands-museum/big-dutch-galleries-close-until-end-of-march-due-to-coronavirus-idUSKBN20Z2MK
# 1195 https://www.reuters.com/article/us-health-coronavirus-uber/uber-to-give-drivers-millions-of-face-masks-to-battle-coronavirus-idUSKCN21R33U
# 1196 https://www.reuters.com/article/us-health-coronavirus-poland-election/polish-presidential-challenger-urges-boycott-of-may-vote-halts-campaign-idUSKBN21G0NQ
# 1197 https://www.reuters.com/article/us-health-coronavirus-usa-congress/mnuchin-hopes-deal-is-very-close-on-2-trillion-coronavirus-aid-package-in-u-s-senate-idUSKBN21A1O0
# 1198 https://www.reuters.com/article/us-health-coronavirus-murphy/u-s-screenwriter-donates-supplies-from-netflix-series-to-help-fight-virus-idUSKBN21A3SC
# 1199 https://www.reuters.com/article/us-health-coronavirus-snooker/world-championship-postponed-over-coronavirus-idUSKBN2171NG
# 1200 https://www.reuters.com/article/us-health-coronavirus-emirates-sport/uae-suspends-all-sporting-events-raising-doubts-about-dubai-world-cup-idUSKBN21621F
# 1201 https://www.reuters.com/article/us-health-coronavirus-jerusalem-islam/muslims-pray-in-thousands-heed-coronavirus-warnings-at-jerusalem-holy-site-idUSKBN2102DL
# 1202 https://www.reuters.com/article/us-cuba-art-censorship/imprisonment-of-cuban-art-ivist-sparks-charges-of-censorship-idUSKBN20X39R
# 1203 https://www.reuters.com/article/us-zimbabwe-sculptor/zimbabwean-artists-dynamic-stone-sculptures-find-global-acclaim-idUSKBN20T0Y4
# 1204 https://www.reuters.com/article/us-health-coronavirus-cannes/cannes-film-festival-will-not-be-held-this-year-in-its-original-form-organisers-idUSKCN21W2EJ
# 1205 https://www.reuters.com/article/us-people-harvey-weinstein/harvey-weinstein-hit-with-third-sexual-assault-case-in-los-angeles-idUSKCN21S24M
# 1206 https://www.reuters.com/article/us-health-coronavirus-britain-scrubs/uk-costume-makers-turn-from-downton-and-star-wars-to-focus-on-scrubs-idUSKCN21S1JI
# 1207 https://www.reuters.com/article/us-health-coronavirus-ellen/quarantine-like-jail-joke-brings-fierce-backlash-for-ellen-degeneres-idUSKCN21Q342
# 1208 https://www.reuters.com/article/us-health-coronavirus-snl/saturday-night-live-returning-with-remotely-produced-tv-show-idUSKCN21R38Z
# 1209 https://www.reuters.com/article/us-health-coronavirus-broadway/broadway-extends-coronavirus-shutdown-through-june-7-idUSKCN21Q2NY
# 1210 https://www.reuters.com/article/us-health-coronavirus-sesame-street/elmo-lin-manuel-miranda-team-up-for-sesame-street-coronavirus-special-idUSKCN21Q37O
# 1211 https://www.reuters.com/article/us-people-harvey-weinstein/harvey-weinstein-free-of-coronavirus-symptoms-spokesman-says-idUSKCN21S00A
# 1212 https://www.reuters.com/article/us-people-john-prine/country-folk-singer-john-prine-dies-at-73-of-coronavirus-complications-idUSKBN21Q06O
# 1213 https://www.reuters.com/article/us-health-coronavirus-bosnia-entertainme/bosnian-band-cheers-up-fans-with-weekly-online-quarantine-show-idUSKBN21P2YO
# 1214 https://www.reuters.com/article/us-quibi-streaming/mobile-only-quibi-sees-more-than-300000-downloads-on-launch-day-sensor-tower-idUSKBN21P2M5
# 1215 https://www.reuters.com/article/us-health-coronavirus-fundraiser/lady-gaga-announces-star-studded-coronavirus-benefit-telecast-idUSKBN21O2I9
# 1216 https://www.reuters.com/article/us-television-quibi/quibi-tests-market-for-quick-hit-videos-with-a-list-stars-idUSKBN21O2M6
# 1217 https://www.reuters.com/article/us-health-coronavirus-jkrowling/harry-potter-author-j-k-rowling-says-fully-recovered-from-likely-coronavirus-idUSKBN21O2KU
# 1218 https://www.reuters.com/article/us-health-coronavirus-usa-concert/country-music-stars-replace-awards-show-with-at-home-performance-special-amid-coronavirus-pandemic-idUSKBN21L38Z
# 1219 https://www.reuters.com/article/us-people-honorblackman/british-bond-girl-honor-blackman-dies-aged-94-idUSKBN21O26T
# 1220 https://www.reuters.com/article/us-health-coronavirus-finland-cake/novelty-toilet-roll-cakes-keep-finnish-baker-in-business-idUSKCN21Q2DO
# 1221 https://www.reuters.com/article/us-health-coronavirus-colombia-sex/sex-toy-sales-take-off-amid-colombias-coronavirus-quarantine-idUSKCN21W0U0
# 1222 https://www.reuters.com/article/us-health-coronavirus-vietnam-burger/eat-it-hanoi-chef-spreads-joy-with-coronaburger-idUSKBN21D0EK
# 1223 https://www.reuters.com/article/us-health-coronavirus-spain-quarantine/who-let-the-dogs-out-a-few-spaniards-defy-coronavirus-lockdown-idUSKBN21C395
# 1224 https://www.reuters.com/news/archive/oddlyEnoughNews
# 1225 https://www.reuters.com/article/us-health-coronavirus-britain-vicar/british-vicar-catches-fire-waiting-for-gods-answer-idUSKBN21C0GM
# 1226 https://www.reuters.com/article/us-health-coronavirus-hongkong-hedgefund/hedge-fund-manager-apologizes-for-wiping-saliva-on-hong-kong-metro-rail-idUSKBN2160IB
# 1227 https://www.reuters.com/article/us-health-coronavirus-germany-toilet-pap/bought-enough-toilet-paper-check-this-online-calculator-idUSKBN21A1YM
# 1228 https://www.reuters.com/article/us-somalia-hyena/somalis-turn-to-dr-hyena-to-fight-depression-mental-illness-idUSKBN20P1AR
# 1229 https://www.reuters.com/news/archive/esgNews
# 1230 https://www.reuters.com/article/us-belgium-cake-bugs/waiter-theres-a-fly-in-my-waffle-belgian-researchers-try-out-insect-butter-idUSKCN20M23U
# 1231 https://www.reuters.com/article/us-eu-tap-bite/biting-passengers-on-flight-is-no-reason-for-cash-compensation-delay-eu-court-adviser-idUSKCN20L1AM
# 1232 https://www.reuters.com/article/us-people-mad-mike/daredevil-mad-mike-hughes-dies-in-crash-of-his-homemade-rocket-in-california-idUSKCN20H0TQ
# 1233 https://www.reuters.com/article/us-safrica-food-milkshakes/cape-town-restaurant-wins-guinness-world-milkshake-record-idUSKBN2011N1
# 1234 https://www.reuters.com/article/us-japan-dogs-toilet/osaka-airport-introduces-canine-comfort-room-complete-with-pole-idUSKBN2041DP
# 1235 https://www.reuters.com/article/us-brazil-tourism/come-to-rio-get-robbed-brazil-tourism-body-shares-awkward-instagram-post-idUSKBN1ZZ2UM
# 1236 https://www.reuters.com/article/us-japan-billionare-maezawa/japanese-billionaire-maezawa-pulls-out-of-dating-show-that-promised-the-moon-idUSKBN1ZT0AD
# 1237 https://www.reuters.com/article/us-australia-bushfires-pizza/lengthy-pizza-delivers-funds-for-embattled-australian-firefighters-idUSKBN1ZL0CR
# 1238 https://www.reuters.com/article/us-sport-trail-jornet/ultra-trail-runner-jornet-beats-base-jumper-in-odd-contest-idUSKBN1ZK2H4
# 1239 https://www.reuters.com/article/us-rugby-union-super-savea/doctor-tiktok-ed-off-with-injured-all-blacks-loose-forward-savea-idUSKBN1ZK0WA
# 1240 https://www.reuters.com/article/us-mexico-beer-el-chapo/drink-like-a-mexican-kingpin-el-chapo-beer-launched-by-daughter-idUSKBN1ZG04Z
# 1241 https://www.reuters.com/article/24-hours-in-pictures-14-apr-2020/top-photos-of-the-day-idUSRTX7CQE2
# 1242 https://www.reuters.com/news/picture/solitary-scenes-in-the-coronavirus-pande-idUSRTS3715N
# 1243 https://www.reuters.com/news/picture/covid-19-rages-through-nursing-homes-idUSRTX7CLL3
# 1244 https://www.reuters.com/news/picture/dozens-killed-as-tornadoes-rip-through-s-idUSRTX7CQWA
# 1245 https://www.reuters.com/news/picture/fire-raging-near-ukraines-chernobyl-idUSRTX7CLRV
# 1246 https://www.reuters.com/news/picture/seattle-artists-struggling-in-coronaviru-idUSRTS38ONT
# 1247 https://www.reuters.com/news/picture/inside-new-york-city-epicenter-of-us-cor-idUSRTS37GAA
# 1248 https://www.reuters.com/news/picture/at-home-with-new-york-city-family-amid-c-idUSRTS37CWR
# 1249 https://www.reuters.com/news/picture/wuhan-begins-to-lift-its-coronavirus-loc-idUSRTS37MZN
# 1250 https://www.reuters.com/news/pictures/archive?page=2&pageSize=9
# 1251 https://www.reuters.com/video/2020/04/01/images-of-march?videoId=706296217&videoChannel=118069
# 1252 https://www.reuters.com/video/2020/02/29/images-of-february?videoId=686982975&videoChannel=118069
# 1253 https://www.reuters.com/video/2020/01/31/images-of-january?videoId=670062931&videoChannel=118069
# 1254 https://www.reuters.com/journalists/maria-caspani
# 1255 https://www.reuters.com/journalists/doina-chiacu
# 1256 https://www.reuters.com/journalists/nathan-layne
# 1257 https://www.reuters.com/journalists/ann-saphir
# 1258 https://www.reuters.com/journalists/jan-wolfe
# 1259 https://www.reuters.com/journalists/lisa-rapaport
# 1260 https://www.reuters.com/journalists/paresh-dave
# 1261 https://www.reuters.com/companies/GOOGL.O
# 1262 https://www.reuters.com/companies/AAPL.O
# 1263 https://www.reuters.com/journalists/ned-parker
# 1264 https://www.reuters.com/journalists/chad-terhune
# 1265 https://www.reuters.com/journalists/medha-singh
# 1266 https://www.reuters.com/journalists/akanksha-rana
# 1267 https://www.reuters.com/companies/JPM.N
# 1268 https://www.reuters.com/companies/WFC.N
# 1269 https://www.reuters.com/companies/JNJ.N
# 1270 https://www.reuters.com/companies/TSLA.O
# 1271 https://www.reuters.com/companies/GM.N
# 1272 https://www.reuters.com/journalists/manas-mishra
# 1273 https://www.reuters.com/journalists/carl-odonnell
# 1274 https://www.reuters.com/journalists/stephen-nellis
# 1275 https://www.reuters.com/journalists/douglas-busvine
# 1276 https://www.reuters.com/journalists/william-schomberg
# 1277 https://www.reuters.com/journalists/andy-bruce
# 1278 https://www.reuters.com/journalists/leigh-thomas
# 1279 https://www.reuters.com/journalists/elizabeth-dilts-marshall
# 1280 https://www.reuters.com/journalists/imani-moise
# 1281 https://www.reuters.com/journalists/anirban-sen
# 1282 https://www.reuters.com/companies/BAC.N
# 1283 https://www.reuters.com/companies/C.N
# 1284 https://www.reuters.com/companies/GS.N
# 1285 https://www.reuters.com/companies/MS.N
# 1286 https://www.reuters.com/journalists/syed-raza-hassan
# 1287 https://www.reuters.com/journalists/natalia-a-ramos-miranda
# 1288 https://www.reuters.com/journalists/jennifer-hiller
# 1289 https://www.reuters.com/companies/VLO.N
# 1290 https://www.reuters.com/companies/PXD.N
# 1291 https://www.reuters.com/companies/PE.N
# 1292 https://www.reuters.com/companies/PAA.N
# 1293 https://www.reuters.com/companies/MRO.N
# 1294 https://www.reuters.com/companies/XOM.N
# 1295 https://www.reuters.com/companies/CVX.N
# 1296 https://www.reuters.com/companies/OXY.N
# 1297 https://www.reuters.com/journalists/david-morgan
# 1298 https://www.reuters.com/journalists/susan-cornwell
# 1299 https://www.reuters.com/article/us-health-coronavirus-britain-toll/united-kingdom-hospital-covid-19-death-toll-rises-by-778-to-12107-idUSKCN21W1UN
# 1300 https://www.reuters.com/journalists/elizabeth-culliford
# 1301 https://www.reuters.com/journalists/makini-brice
# 1302 https://www.reuters.com/companies/AMZN.O
# 1303 https://www.reuters.com/journalists/greg-torode
# 1304 https://www.reuters.com/journalists/james-pomfret
# 1305 https://www.reuters.com/journalists/jessie-pang
# 1306 https://www.reuters.com/journalists/felix-tam
# 1307 https://www.reuters.com/journalists/andrew-hay
# 1308 https://www.reuters.com/journalists/shariq-khan
# 1309 https://www.reuters.com/journalists/arathy-s-nair
# 1310 https://www.reuters.com/companies/WLL.N
# 1311 https://www.reuters.com/companies/TGE.N
# 1312 https://www.reuters.com/companies/BX.N
# 1313 https://www.reuters.com/journalists/david-henry
# 1314 https://www.reuters.com/companies/SPR.N
# 1315 https://www.reuters.com/companies/BA.N
# 1316 https://www.reuters.com/companies/AIR.PA
# 1317 https://www.reuters.com/journalists/steve-holland
# 1318 https://www.reuters.com/journalists/trevor-hunnicutt
# 1319 https://www.reuters.com/journalists/david-lawder
# 1320 https://www.reuters.com/journalists/david-shepardson
# 1321 https://www.reuters.com/journalists/rachit-vats
# 1322 https://www.reuters.com/companies/GOLL4.SA
# 1323 https://www.reuters.com/journalists/paola-luelmo
# 1324 https://www.reuters.com/journalists/estelle-shirbon
# 1325 https://www.reuters.com/news/picture/spring-in-blossom-idUSRTS36XBF
# 1326 https://www.reuters.com/news/picture/top-photos-of-the-day-idUSRTS38R1N
# 1327 https://www.reuters.com/news/picture/photos-of-the-week-idUSRTS38MDV
# 1328 https://www.reuters.com/news/picture/top-photos-of-the-day-idUSRTS38LMP
# 1329 https://www.reuters.com/news/picture/top-photos-of-the-day-idUSRTS38I8L
# 1330 https://www.reuters.com/news/picture/portrait-of-a-frontline-coronavirus-work-idUSRTS38BBS
# 1331 https://www.reuters.com/news/picture/celebrating-easter-during-a-pandemic-idUSRTS38N87
# 1332 https://www.reuters.com/news/picture/prisoners-at-risk-for-infection-in-coron-idUSRTS38GXF
# 1333 https://www.reuters.com/journalists/john-whitesides
# 1334 https://www.reuters.com/journalists/julia-harte
# 1335 https://www.reuters.com/journalists/sudip-kar-gupta
# 1336 https://www.reuters.com/journalists/yilei-sun
# 1337 https://www.reuters.com/companies/RENA.PA
# 1338 https://www.reuters.com/companies/0489.HK
# 1339 https://www.reuters.com/companies/7201.T
# 1340 https://www.reuters.com/companies/1114.HK
# 1341 https://www.reuters.com/companies/7269.T
# 1342 https://www.reuters.com/companies/000625.SZ
# 1343 https://www.reuters.com/companies/PEUP.PA
# 1344 https://www.reuters.com/companies/SAPG.DE
# 1345 https://www.reuters.com/companies/600030.SS
# 1346 https://www.reuters.com/companies/6030.HK
# 1347 https://www.reuters.com/companies/601066.SS
# 1348 https://www.reuters.com/companies/6066.HK
# 1349 https://www.reuters.com/article/uk-factcheck-coronavirus-soap-cure/false-claim-if-soap-can-kill-coronavirus-there-should-be-a-cure-idUSKCN21W25D
# 1350 https://www.reuters.com/article/uk-factcheck-medication-fever-coronaviru/false-claim-avoid-medications-to-lower-fever-if-sick-with-covid-19-idUSKCN21W259
# 1351 https://www.reuters.com/article/uk-factcheck-coronavirus-introducing-mar/false-claim-u-s-coronavirus-response-slowly-introducing-martial-law-idUSKCN21W250
# 1352 https://www.reuters.com/article/uk-factcheck-boris-johnson-leaving-icu/false-claim-video-shows-british-pm-boris-johnson-leaving-intensive-care-idUSKCN21V1Z2
# 1353 https://www.reuters.com/article/uk-factcheck-5g-mast-sign/false-claim-hazard-sign-warns-of-radiation-from-5g-mast-idUSKCN21U0J4
# 1354 https://www.reuters.com/article/uk-factcheck-coronavirus-pelosi-raise/false-claim-pelosi-asked-for-a-salary-raise-while-trump-donated-his-pay-idUSKCN21R3K0
# 1355 https://www.reuters.com/article/uk-factcheck-coronavirus-nostradamus/false-claim-nostradamus-predicted-the-coronavirus-outbreak-idUSKCN21R388
# 1356 https://www.reuters.com/article/uk-factcheck-lockdown-italians-money/false-claim-italians-are-throwing-money-onto-the-streets-amidst-lockdown-idUSKCN21R2UU
# 1357 https://www.reuters.com/article/uk-factcheck-natural-viruses/false-claimnatural-viruses-require-natural-cures-not-vaccines-idUSKCN21R2QB
# 1358 https://www.reuters.com/article/uk-factcheck-coronavirus-facemasks-fire/true-claim-face-masks-catch-fire-if-microwaved-idUSKCN21R2M5
# 1359 https://www.reuters.com/news/archive/reuterscomservice?view=page&page=2&pageSize=10

# %% [markdown]
# ## 2.5 Index statistics

# %%
# load index, doc_lengths and doc_urls
with open('inverted_index.p', 'rb') as fp:
    index = pickle.load(fp)
with open('doc_lengths.p', 'rb') as fp:
    doc_lengths = pickle.load(fp)
with open('doc_urls.p', 'rb') as fp:
    doc_urls = pickle.load(fp)

# %%
print('Total index length', len(index))
print('\nTop terms by number of documents they apperared in:')
sorted_by_n_docs = sorted(index.items(), key=lambda kv: (len(kv[1]), kv[0]), reverse=True)
print([(sorted_by_n_docs[i][0], len(sorted_by_n_docs[i][1])) for i in range(20)])
print('\nTop terms by overall frequency:')
sorted_by_freq = sorted(index.items(), key=lambda kv: (kv[1][0], kv[0]), reverse=True)
print([(sorted_by_freq[i][0], sorted_by_freq[i][1][0]) for i in range(20)])
# Out:
# Total index length 11565
#
# Top terms by number of documents they apperared in:
# [('reuter', 683), ('said', 640), ('s', 610), ('have', 513), ('coronaviru', 507), ('ha', 501), ('wa', 497), ('but', 426), ('thi', 425), ('not', 419), ('which', 418), ('more', 411), ('than', 370), ('their', 365), ('new', 363), ('after', 360), ('been', 357), ('would', 356), ('had', 349), ('also', 348)]
#
# Top terms by overall frequency:
# [('said', 3174), ('s', 2903), ('have', 1607), ('wa', 1467), ('ha', 1400), ('coronaviru', 1092), ('not', 1089), ('but', 1037), ('reuter', 969), ('we', 945), ('thi', 944), ('more', 911), ('would', 870), ('they', 848), ('their', 836), ('had', 824), ('state', 789), ('which', 783), ('new', 770), ('year', 756)]

# %% [markdown]
# # 3. Answering query

# %% [markdown]
# Now, given already built inverted index, it's time to utilize it for answering user queries. In this class there are two implemented methods:
# - `boolean_retrieval`, the simplest form of document retrieval which returns a set of documents such that each one contains all query terms. Returns a set of document ids. Refer to *ch.1* of the book for details;
# - `okapi_scoring`, Okapi BM25 ranking function - assigns scores to documents in the collection that are relevant to the user query. Returns a dictionary of scores, `doc_id:score`. Read about it in [Wikipedia](https://en.wikipedia.org/wiki/Okapi_BM25#The_ranking_function) and implement accordingly.
#
# Both methods accept `query` parameter in a form of a dictionary, `term:frequency`

# %%
from collections import Counter
import math


class QueryProcessing:

    @staticmethod
    def prepare_query(raw_query):
        prep = Preprocessor()
        # pre-process query the same way as documents
        query = prep.preprocess(raw_query)
        # count frequency
        return Counter(query)

    @staticmethod
    def boolean_retrieval(query, index):
        """ retrieve a set of documents containing all query terms """ 
        terms_docs_intersection = None

        for query_term in query:
            term_docs = set()
            for index_element in index[query_term]:
                if isinstance(index_element, tuple):
                    term_docs.add(index_element[0])

            if terms_docs_intersection is None:
                terms_docs_intersection = term_docs
            else:
                terms_docs_intersection = terms_docs_intersection.intersection(term_docs)

        return terms_docs_intersection

    @staticmethod
    def okapi_scoring(query, doc_lengths, index, k1=1.2, b=0.75):
        relevant_docs_scores = {}

        def calculate_avg_num_words_in_docs():
            avg_d = 0
            for _, doc_length in doc_lengths.items():
                avg_d += doc_length
            return avg_d / len(doc_lengths)

        # idf_sum = 0
        N = len(doc_lengths)
        avg_d = calculate_avg_num_words_in_docs()

        for query_term in query:
            if query_term not in index:
                continue

            n_q = len(index[query_term]) - 1  # num of docs containing term q.
            idf_q = math.log((N - n_q + 0.5) / (n_q + 0.5))

            for index_element in index[query_term]:
                if isinstance(index_element, tuple):
                    # number of times term q appears in doc D:
                    f_q = index_element[1]
                    doc_id = index_element[0]
                    D = doc_lengths[doc_id]  # number of words in doc d

                    # BM25 score for document d:
                    score_d = idf_q * f_q * (k1 + 1) / (f_q + k1 * (1 - b + b * D / avg_d))

                    if doc_id not in relevant_docs_scores:
                        relevant_docs_scores[doc_id] = score_d
                    else:
                        relevant_docs_scores[doc_id] += score_d

        return relevant_docs_scores

# %% [markdown]
# ## 3.1 Tests

# %%
test_doc_lengths = {1: 20, 2: 15, 3: 10, 4:20, 5:30}
test_index = {'x': [2, (1, 1), (2, 1)], 'y': [2, (1, 1), (3, 1)], 'z': [3, (2, 1), (4,2)]}


test_query1 = QueryProcessing.prepare_query('x z')
test_query2 = QueryProcessing.prepare_query('x y')


assert QueryProcessing.boolean_retrieval(test_query1, test_index) == {2}
assert QueryProcessing.boolean_retrieval(test_query2, test_index) == {1}
okapi_res = QueryProcessing.okapi_scoring(test_query2, test_doc_lengths, test_index)
assert all(k in okapi_res for k in (1,2,3))
assert not any(k in okapi_res for k in (4,5))
assert okapi_res[1] > okapi_res[3] > okapi_res[2]

# %% [markdown]
# # 4. Setting up a server

# %% [markdown]
# The resulting search engine is organized as a web-service that gets a query from get-parameters and returns urls with scores as a `json` dictionary. It is work in a browser of with curl, and look smth like this:
#
# `> curl localhost:8080/?q=some_query_text
# { "url1" : 0.9, "url2": 0.8 }`

# %%
import socketserver
import json
from http.server import SimpleHTTPRequestHandler
from urllib import parse

PORT_NUMBER = 8080


class MyHandler(SimpleHTTPRequestHandler):

    def do_GET(self):
        
        def create_urls_scores(okapi_scores):
            sorted_scores = {k: v for k, v in sorted(okapi_scores.items(), key=lambda item: item[1], reverse=True)}

            urls_scores = {}
            for doc_id, okapi_score in sorted_scores.items():
                doc_url = indexer.doc_urls[doc_id]
                urls_scores[doc_url] = okapi_score
            
            return json.dumps(urls_scores).encode()
        
        self.send_response(200)
        self.send_header('Content-type', 'application/json')
        self.end_headers()

        raw_query = parse.parse_qsl(parse.urlsplit(self.path).query)[0][1]
#         print(raw_query)
        query = QueryProcessing.prepare_query(raw_query)
        okapi_scores = QueryProcessing.okapi_scoring(query, indexer.doc_lengths, indexer.index)
        self.wfile.write(create_urls_scores(okapi_scores))

with socketserver.TCPServer(("", PORT_NUMBER), MyHandler) as httpd:
    print("serving at port", PORT_NUMBER)
    httpd.serve_forever()
# Out:
# serving at port 8080
# 127.0.0.1 - - [14/Apr/2020 11:49:26] "GET /?q=Trump HTTP/1.1" 200 -
